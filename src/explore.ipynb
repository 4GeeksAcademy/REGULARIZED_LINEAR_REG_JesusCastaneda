# %% [markdown]
# # Explore here

# %%
# Your code here
import pandas as pd
import requests

# URL del archivo CSV
url = "https://raw.githubusercontent.com/4GeeksAcademy/regularized-linear-regression-project-tutorial/main/demographic_health_data.csv"

# Hacer una solicitud GET para obtener el archivo
response = requests.get(url)

# Verificar si la solicitud fue exitosa (código 200)
if response.status_code == 200:
    # Guardar el contenido del archivo en la carpeta data/raw
    with open("/workspaces/REGULARIZED_LINEAR_REG_JesusCastaneda/data/raw/demographic_health_data.csv", "wb") as f:
        f.write(response.content)
else:
    print("Error al descargar el archivo:", response.status_code)

# %%
df = pd.read_csv(url)
df
# Out:
#        fips  TOT_POP    0-9  0-9 y/o % of total pop  19-Oct  \
# 0      1001    55601   6787               12.206615    7637
# 1      1003   218022  24757               11.355276   26913
# 2      1005    24881   2732               10.980266    2960
# 3      1007    22400   2456               10.964286    2596
# 4      1009    57840   7095               12.266598    7570
# ...     ...      ...    ...                     ...     ...
# 3135  56037    43051   6104               14.178532    6326
# 3136  56039    23081   2384               10.328842    2185
# 3137  56041    20299   3121               15.375142    3205
# 3138  56043     7885    858               10.881420    1113
# 3139  56045     6967    780               11.195637     779
#
#       10-19 y/o % of total pop  20-29  20-29 y/o % of total pop  30-39  \
# 0                    13.735364   6878                 12.370281   7089
# 1                    12.344167  23579                 10.814964  25213
# ...

# %%
#Tamano
print("El tamano es de:", df.shape)
# Out:
# El tamano es de: (3140, 108)

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3140 entries, 0 to 3139
# Data columns (total 108 columns):
#  #    Column                                                                         Dtype
# ---   ------                                                                         -----
#  0    fips                                                                           int64
#  1    TOT_POP                                                                        int64
#  2    0-9                                                                            int64
#  3    0-9 y/o % of total pop                                                         float64
#  4    19-Oct                                                                         int64
#  5    10-19 y/o % of total pop                                                       float64
#  6    20-29                                                                          int64
# ...

# %%
round(df.describe(),2)
# Out:
#            fips      TOT_POP        0-9  0-9 y/o % of total pop      19-Oct  \
# count   3140.00      3140.00     3140.0                 3140.00     3140.00
# mean   30401.64    104189.41    12740.3                   11.87    13367.98
# std    15150.56    333583.40    41807.3                    2.12    42284.39
# min     1001.00        88.00        0.0                    0.00        0.00
# 25%    18180.50     10963.25     1280.5                   10.59     1374.50
# 50%    29178.00     25800.50     3057.0                   11.80     3274.00
# 75%    45081.50     67913.00     8097.0                   12.95     8822.25
# max    56045.00  10105518.00  1208253.0                   25.46  1239139.00
#
#        10-19 y/o % of total pop       20-29  20-29 y/o % of total pop  \
# count                   3140.00     3140.00                   3140.00
# mean                      12.69    14469.33                     12.28
# std                        1.82    49577.73                      3.13
# ...

# %%
df.head()
# Out:
#    fips  TOT_POP    0-9  0-9 y/o % of total pop  19-Oct  \
# 0  1001    55601   6787               12.206615    7637
# 1  1003   218022  24757               11.355276   26913
# 2  1005    24881   2732               10.980266    2960
# 3  1007    22400   2456               10.964286    2596
# 4  1009    57840   7095               12.266598    7570
#
#    10-19 y/o % of total pop  20-29  20-29 y/o % of total pop  30-39  \
# 0                 13.735364   6878                 12.370281   7089
# 1                 12.344167  23579                 10.814964  25213
# 2                 11.896628   3268                 13.134520   3201
# 3                 11.589286   3029                 13.522321   3113
# 4                 13.087828   6742                 11.656293   6884
#
#    30-39 y/o % of total pop  ...  COPD_number  diabetes_prevalence  \
# 0                 12.749771  ...         3644                 12.9
# 1                 11.564429  ...        14692                 12.0
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# fips                      0
# TOT_POP                   0
# 0-9                       0
# 0-9 y/o % of total pop    0
# 19-Oct                    0
#                          ..
# CKD_prevalence            0
# CKD_Lower 95% CI          0
# CKD_Upper 95% CI          0
# CKD_number                0
# Urban_rural_code          0
# Length: 108, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

fig, axis = plt.subplots(1, 2, figsize = (10, 7))
# Crear un histograma múltiple
sns.histplot(ax= axis[0],data = df, x = "COUNTY_NAME").set_xticks([])
sns.histplot(ax= axis[1],data = df, x = "STATE_NAME").set_xticks([])

# Ajustar el layout
plt.tight_layout()

# Mostrar el plot
plt.show()

# %%
df['STATE_NAME'].value_counts()
# Out:
# STATE_NAME
# Texas                   254
# Georgia                 159
# Virginia                133
# Kentucky                120
# Missouri                115
# Kansas                  105
# Illinois                102
# North Carolina          100
# Iowa                     99
# Tennessee                95
# Nebraska                 93
# Indiana                  92
# Ohio                     88
# Minnesota                87
# Michigan                 83
# Mississippi              82
# Oklahoma                 77
# Arkansas                 75
# Wisconsin                72
# Pennsylvania             67
# Alabama                  67
# Florida                  67
# South Dakota             66
# Louisiana                64
# Colorado                 64
# New York                 62
# California               58
# Montana                  56
# West Virginia            55
# North Dakota             53
# South Carolina           46
# Idaho                    44
# ...

# %%
df['COUNTY_NAME'].value_counts()
# Out:
# COUNTY_NAME
# Washington    31
# Jefferson     26
# Lincoln       24
# Franklin      24
# Jackson       24
#               ..
# Vilas          1
# Washburn       1
# Waukesha       1
# Waupaca        1
# Waushara       1
# Name: count, Length: 1841, dtype: int64

# %%
df["STATE_NAME"] = pd.factorize(df["STATE_NAME"])[0]
df["COUNTY_NAME"] = pd.factorize(df["COUNTY_NAME"])[0]

# %%
# Buscar correlaciones bajas (-0.3<x<0.3) con la variable objetivo "Heart disease_prevalence" para eliminar columnas innecesarias

# Calculo todas las correlaciones numéricas
correlaciones = df.corr(numeric_only=True)

# Extraer solo la fila/columna relacionada con mi variable objetivo
cor_target = correlaciones[['Heart disease_prevalence']].sort_values(by='Heart disease_prevalence', ascending=False)

# Heatmap de una sola columna
plt.figure(figsize=(5, 15))
sns.heatmap(cor_target, annot=True, cmap='coolwarm', fmt=".2f", vmin=-1, vmax=1)
plt.title("Correlación con Heart disease_prevalence")

plt.show()

# %%
from sklearn.feature_selection import SelectKBest, f_classif

# Supongamos que ya tienes X (atributos) e y (etiquetas)
selector = SelectKBest(score_func=f_classif, k=20)  # Elegimos las 20 mejores
X_reducido = selector.fit_transform(X, y)

# Ver los nombres de las columnas seleccionadas
columnas_seleccionadas = X.columns[selector.get_support()].tolist()

print("Columnas seleccionadas:")
print(columnas_seleccionadas)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 5
#       3 # Supongamos que ya tienes X (atributos) e y (etiquetas)
#       4 selector = SelectKBest(score_func=f_classif, k=20)  # Elegimos las 20 mejores
# ----> 5 X_reducido = selector.fit_transform(X, y)
#       7 # Ver los nombres de las columnas seleccionadas
#       8 columnas_seleccionadas = X.columns[selector.get_support()].tolist()
#
# NameError: name 'X' is not defined
